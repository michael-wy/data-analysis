# %%
a=["战狼2","速度与激情8","功夫瑜伽","西游伏妖篇","变形金刚5:最后的战士","摔跤吧!爸爸","加勒比海盗5:死无对证","金刚:骷髅岛",
  "极限特工:终极回归","生化危机6:终章","乘风破浪","神偷奶爸3","智取威虎山","大闹天竺","金刚3:殊死一战","蜘蛛侠:英雄归来",
  "悟空传","银河护卫队2","情圣","新木乃伊"]
b=[56.01,26.94,17.53,16.49,15.45,12.96,11.8,11.61,11.28,11.12,10.49,10.3,8.75,7.55,7.32,6.99,6.88,6.86,6.58,6.23]单位:亿

# %%
a=["战狼2","速度与激情8","功夫瑜伽","西游伏妖篇","变形金刚5:最后的战士","摔跤吧!爸爸","加勒比海盗5:死无对证","金刚:骷髅岛",
  "极限特工:终极回归","生化危机6:终章","乘风破浪","神偷奶爸3","智取威虎山","大闹天竺","金刚3:殊死一战","蜘蛛侠:英雄归来",
  "悟空传","银河护卫队2","情圣","新木乃伊"]
print(len(a))
# Out:
# 20

# %%
b=[56.01,26.94,17.53,16.49,15.45,12.96,11.8,11.61,11.28,11.12,10.49,10.3,8.75,7.55,7.32,6.99,6.88,6.86,6.58,6.23]
print(len(b))
# Out:
# 20

# %%
X轴，Y轴不能直接传入字符串进去

# %%
from matplotlib import pyplot as plt
from matplotlib import font_manager
a=["战狼2","速度与激情8","功夫瑜伽","西游伏妖篇","变形金刚5:最后的战士","摔跤吧!爸爸","加勒比海盗5:死无对证","金刚:骷髅岛",
  "极限特工:终极回归","生化危机6:终章","乘风破浪","神偷奶爸3","智取威虎山","大闹天竺","金刚3:殊死一战","蜘蛛侠:英雄归来",
  "悟空传","银河护卫队2","情圣","新木乃伊"]
b=[56.01,26.94,17.53,16.49,15.45,12.96,11.8,11.61,11.28,11.12,10.49,10.3,8.75,7.55,7.32,6.99,6.88,6.86,6.58,6.23]

plt.bar(range(len(a)),b)#range(len(a))表示定位在x处，b表示数据的高度
plt.xticks(range(len(a)),a)#
plt.show()

# %%
from matplotlib import pyplot as plt
from matplotlib import font_manager
my_font=font_manager.FontProperties(fname="C:\\Windows\\Fonts\\msyh.ttf")
a=["战狼2","速度与激情8","功夫瑜伽","西游伏妖篇","变形金刚5:最后的战士","摔跤吧!爸爸","加勒比海盗5:死无对证","金刚:骷髅岛",
  "极限特工:终极回归","生化危机6:终章","乘风破浪","神偷奶爸3","智取威虎山","大闹天竺","金刚3:殊死一战","蜘蛛侠:英雄归来",
  "悟空传","银河护卫队2","情圣","新木乃伊"]
b=[56.01,26.94,17.53,16.49,15.45,12.96,11.8,11.61,11.28,11.12,10.49,10.3,8.75,7.55,7.32,6.99,6.88,6.86,6.58,6.23]

plt.bar(range(len(a)),b,width=0.3)#range(len(a))表示定位在x处，b表示数据的高度
plt.xticks(range(len(a)),a,fontproperties=my_font,rotation=45)#
plt.show()

# %%
plt.bar(range(len(a)),b,width=0.3)#range(len(a))表示定位在x处，b表示数据的高度
plt.xticks(range(len(a)),a,fontproperties=my_font,rotation=45)#

# %%
from matplotlib import pyplot as plt
from matplotlib import font_manager
my_font=font_manager.FontProperties(fname="C:\\Windows\\Fonts\\msyh.ttf")
a=["战狼2","速度与激情8","功夫瑜伽","西游伏妖篇","变形金刚5:最后的战士","摔跤吧!爸爸","加勒比海盗5:死无对证","金刚:骷髅岛",
  "极限特工:终极回归","生化危机6:终章","乘风破浪","神偷奶爸3","智取威虎山","大闹天竺","金刚3:殊死一战","蜘蛛侠:英雄归来",
  "悟空传","银河护卫队2","情圣","新木乃伊"]
b=[56.01,26.94,17.53,16.49,15.45,12.96,11.8,11.61,11.28,11.12,10.49,10.3,8.75,7.55,7.32,6.99,6.88,6.86,6.58,6.23]
#设置图形大小
plt.figure(figsize=(20,8),dpi=80)
#绘制条形图
plt.bar(range(len(a)),b,width=0.3)#range(len(a))表示定位在x处，b表示数据的高度
#设置字符串在X轴上
plt.xticks(range(len(a)),a,fontproperties=my_font,rotation=45)#
plt.show()

# %%
#设置图形大小
plt.figure(figsize=(20,8),dpi=80)

# %%
名字太长了怎么办  用\n给他换行

# %%
from matplotlib import pyplot as plt
from matplotlib import font_manager
my_font=font_manager.FontProperties(fname="C:\\Windows\\Fonts\\msyh.ttf")
a=["战狼2","速度与激情8","功夫瑜伽","西游伏妖篇","变形金刚5:\n最后的战士","摔跤吧!爸爸","加勒比海盗5:\n死无对证","金刚:骷髅岛",
  "极限特工:\n终极回归","生化危机6:\n终章","乘风破浪","神偷奶爸3","智取威虎山","大闹天竺","金刚3:\n殊死一战","蜘蛛侠:\n英雄归来",
  "悟空传","银河护卫队2","情圣","新木乃伊"]
b=[56.01,26.94,17.53,16.49,15.45,12.96,11.8,11.61,11.28,11.12,10.49,10.3,8.75,7.55,7.32,6.99,6.88,6.86,6.58,6.23]
#设置图形大小
plt.figure(figsize=(20,8),dpi=80)
#绘制条形图
plt.bar(range(len(a)),b,width=0.3)#range(len(a))表示定位在x处，b表示数据的高度
#设置字符串在X轴上
plt.xticks(range(len(a)),a,fontproperties=my_font,rotation=90)#
plt.show()

# %%
但是呢  还不是很理想  那么给整个图旋转  绘制一个横着的条形图

# %%
from matplotlib import pyplot as plt
from matplotlib import font_manager
my_font=font_manager.FontProperties(fname="C:\\Windows\\Fonts\\msyh.ttf")
a=["战狼2","速度与激情8","功夫瑜伽","西游伏妖篇","变形金刚5:\n最后的战士","摔跤吧!爸爸","加勒比海盗5:\n死无对证","金刚:骷髅岛",
  "极限特工:\n终极回归","生化危机6:\n终章","乘风破浪","神偷奶爸3","智取威虎山","大闹天竺","金刚3:\n殊死一战","蜘蛛侠:\n英雄归来",
  "悟空传","银河护卫队2","情圣","新木乃伊"]
b=[56.01,26.94,17.53,16.49,15.45,12.96,11.8,11.61,11.28,11.12,10.49,10.3,8.75,7.55,7.32,6.99,6.88,6.86,6.58,6.23]
#设置图形大小
plt.figure(figsize=(20,8),dpi=80)
#绘制条形图
plt.barh(range(len(a)),b,height=0.3)#range(len(a))表示定位在x处，b表示数据的高度
#设置字符串在X轴上
plt.xticks(range(len(a)),a,fontproperties=my_font,rotation=90)#
plt.show()

# %%
plt.barh??

# %%
from matplotlib import pyplot as plt
from matplotlib import font_manager
my_font=font_manager.FontProperties(fname="C:\\Windows\\Fonts\\msyh.ttf")
a=["战狼2","速度与激情8","功夫瑜伽","西游伏妖篇","变形金刚5:最后的战士","摔跤吧!爸爸","加勒比海盗5:死无对证","金刚:骷髅岛",
  "极限特工:\n终极回归","生化危机6:终章","乘风破浪","神偷奶爸3","智取威虎山","大闹天竺","金刚3:殊死一战","蜘蛛侠:英雄归来",
  "悟空传","银河护卫队2","情圣","新木乃伊"]
b=[56.01,26.94,17.53,16.49,15.45,12.96,11.8,11.61,11.28,11.12,10.49,10.3,8.75,7.55,7.32,6.99,6.88,6.86,6.58,6.23]
#设置图形大小
plt.figure(figsize=(20,8),dpi=80)
#绘制条形图
plt.barh(range(len(a)),b,height=0.3,color="orange")#range(len(a))表示定位在x处，b表示数据的高度
#设置字符串在y轴上
plt.yticks(range(len(a)),a,fontproperties=my_font,rotation=0)#
plt.show()

# %%
#绘制条形图
plt.barh(range(len(a)),b,height=0.3,color="orange")#range(len(a))表示定位在x处，b表示数据的高度
#设置字符串在y轴上
plt.yticks(range(len(a)),a,fontproperties=my_font,rotation=0)#

# %%
为什么会绘制网格呢，因为有些具体的点看的不是很清楚，有了网格看的更清楚一些

# %%
from matplotlib import pyplot as plt
from matplotlib import font_manager
    my_font=font_manager.FontProperties(fname="C:\\Windows\\Fonts\\msyh.ttf")
a=["战狼2","速度与激情8","功夫瑜伽","西游伏妖篇","变形金刚5:最后的战士","摔跤吧!爸爸","加勒比海盗5:死无对证","金刚:骷髅岛",
  "极限特工:\n终极回归","生化危机6:终章","乘风破浪","神偷奶爸3","智取威虎山","大闹天竺","金刚3:殊死一战","蜘蛛侠:英雄归来",
  "悟空传","银河护卫队2","情圣","新木乃伊"]
b=[56.01,26.94,17.53,16.49,15.45,12.96,11.8,11.61,11.28,11.12,10.49,10.3,8.75,7.55,7.32,6.99,6.88,6.86,6.58,6.23]
#设置图形大小
plt.figure(figsize=(20,8),dpi=80)
#绘制条形图
plt.barh(range(len(a)),b,height=0.3,color="orange")#range(len(a))表示定位在x处，b表示数据的高度
#设置字符串在y轴上
plt.yticks(range(len(a)),a,fontproperties=my_font,rotation=0)#
#绘制网格
plt.grid(alpha=0.3)
plt.show()

# %%
plt.grid(alpha=0.3)
这样很清楚明了的看出战狼2的票房要远远高于速度与激情8，差不多要高出一倍
这个样子就好多了吧，这个图到这就绘制完成了
# Out:
#   File "<ipython-input-21-da7c3dfe74c0>", line 2
#     这样很清楚明了的看出战狼2的票房要远远高于速度与激情8，差不多要高出一倍
#                                        ^
# SyntaxError: invalid character in identifier

# %%
假设你知道了列表a中电影分别在2017-09-14(b_14),2017-09-15(b_15),2017-09-16(b_16)三天的票房，为了展示列表中电影本身的票房以及同其他
电影的数据对比情况，应该如何更加直观的呈现该数据？
a=["猩球崛起3:终极之战","敦刻尔克","蜘蛛侠:英雄归来","战狼2"]
b_16=[15746,312,4497,319]
b_15=[12357,156,2045,168]
b_14=[2358,399,2358,362]

# %%
a=["猩球崛起3:终极之战","敦刻尔克","蜘蛛侠:英雄归来","战狼2"]
a=range(len(a))
print(a)
b=list(range(len(a)))
print(b)
# Out:
# range(0, 4)
# [0, 1, 2, 3]

# %%
from matplotlib import pyplot as plt
from matplotlib import font_manager
a=["猩球崛起3:终极之战","敦刻尔克","蜘蛛侠:英雄归来","战狼2"]
b_16=[15746,312,4497,319]
b_15=[12357,156,2045,168]
b_14=[2358,399,2358,362]
bar_width=0.2
x_14=list(range(len(a)))
x_15=[i + bar_width for i in x_14]#避免重合，所以在x轴上要错开一个位置
x_16=[i + bar_width*2 for i in x_14]
#设置图形大小
plt.figure(figsize=(20,8),dpi=80)
plt.bar(range(len(a)),b_14,width=bar_width)
plt.bar(x_15,b_15,width=bar_width)
plt.bar(x_16,b_16,width=bar_width)
plt.show()

# %%
from matplotlib import pyplot as plt
from matplotlib import font_manager
my_font=font_manager.FontProperties(fname="C:\\Windows\\Fonts\\msyh.ttf")
a=["猩球崛起3:终极之战","敦刻尔克","蜘蛛侠:英雄归来","战狼2"]
b_16=[15746,312,4497,319]
b_15=[12357,156,2045,168]
b_14=[2358,399,2358,362]
bar_width=0.2
x_14=list(range(len(a)))
x_15=[i + bar_width for i in x_14]#避免重合，所以在x轴上要错开一个位置
x_16=[i + bar_width*2 for i in x_14]
#设置图形大小
plt.figure(figsize=(20,8),dpi=80)
plt.bar(range(len(a)),b_14,width=bar_width)
plt.bar(x_15,b_15,width=bar_width)
plt.bar(x_16,b_16,width=bar_width)
#设置X轴的刻度
plt.xticks(x_15,a,fontproperties=my_font)
plt.show()

# %%
my_font=font_manager.FontProperties(fname="C:\\Windows\\Fonts\\msyh.ttf")
plt.xticks(x_15,a,fontproperties=my_font)

# %%
from matplotlib import pyplot as plt
from matplotlib import font_manager
my_font=font_manager.FontProperties(fname="C:\\Windows\\Fonts\\msyh.ttf")
a=["猩球崛起3:终极之战","敦刻尔克","蜘蛛侠:英雄归来","战狼2"]
b_16=[15746,312,4497,319]
b_15=[12357,156,2045,168]
b_14=[2358,399,2358,362]
bar_width=0.2
x_14=list(range(len(a)))
x_15=[i + bar_width for i in x_14]#避免重合，所以在x轴上要错开一个位置
x_16=[i + bar_width*2 for i in x_14]
#设置图形大小
plt.figure(figsize=(20,8),dpi=80)
plt.bar(range(len(a)),b_14,width=bar_width,label="9月14日")
plt.bar(x_15,b_15,width=bar_width,label="9月14日")
plt.bar(x_16,b_16,width=bar_width,label="9月14日")
#设置图例
plt.legend(prop=my_font)
#设置X轴的刻度
plt.xticks(x_15,a,fontproperties=my_font)
plt.show()

# %%
plt.legend??
