# %%
import pandas as pd
s1=pd.Series(["a","b","c","d"])
s1
# Out:
# 0    a
# 1    b
# 2    c
# 3    d
# dtype: object

# %%
s2=pd.Series([1,2,3,4],index=["a","b","c","d"])
s2["a":"c"]
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
s3=pd.Series({"a":1,"b":2,"c":3,"d":4})
s3
# Out:
# a    1
# b    2
# c    3
# d    4
# dtype: int64

# %%
s1.index
s2.index
# Out:
# Index(['a', 'b', 'c', 'd'], dtype='object')

# %%
s1.values
# Out:
# array(['a', 'b', 'c', 'd'], dtype=object)

# %%
s2.values
# Out:
# array([1, 2, 3, 4], dtype=int64)

# %%
import pandas as pd
df1=pd.DataFrame({"a","b","c","d"})
df1
# Out:
#    0
# 0  a
# 1  d
# 2  b
# 3  c

# %%
df2=pd.DataFrame([["a","A"],["b","B"],["c","C"],["d","D"]])
df2
# Out:
#    0  1
# 0  a  A
# 1  b  B
# 2  c  C
# 3  d  D

# %%
df3=pd.DataFrame([('a','A'),('b','B'),('c','C'),('d','D')])
df3
# Out:
#    0  1
# 0  a  A
# 1  b  B
# 2  c  C
# 3  d  D

# %%
import pandas as pd
df31=pd.DataFrame([["a","A"],["b","B"],["c","C"],["d","D"]],columns=["小写","大写"])
df31
# Out:
#   小写 大写
# 0  a  A
# 1  b  B
# 2  c  C
# 3  d  D

# %%
df32=pd.DataFrame([["a","A"],["b","B"],["c","C"],["d","D"]],index=["一","二","三","四"])
df32
# Out:
#    0  1
# 一  a  A
# 二  b  B
# 三  c  C
# 四  d  D

# %%
df33=pd.DataFrame([["a","A"],["b","B"],["c","C"],["d","D"]],columns=["小写","大学"],index=["一","二","三","四"])
df33
# Out:
#   小写 大学
# 一  a  A
# 二  b  B
# 三  c  C
# 四  d  D

# %%
data={"小写":["a","b","c","d"],"大写":["A","B","C","D"]}
df34=pd.DataFrame(data,index=["一","二","三","四"])

df34
# Out:
#   小写 大写
# 一  a  A
# 二  b  B
# 三  c  C
# 四  d  D

# %%
import pandas as pd
df=pd.read_excel(r"H:\对比Excel,轻松学习Python数据分析数据集\4zhang.xlsx")
df
# Out:
#    编号  年龄 性别       注册时间
# 0  A1  54  男 2018-08-08
# 1  A2  16  女 2018-08-09
# 2  A3  47  女 2018-08-10
# 3  A4  41  男 2018-08-11

# %%
df1=pd.read_excel(r"H:\对比Excel,轻松学习Python数据分析数据集\4zhang.xlsx",sheet_name="Sheet1")
df1
# Out:
#    编号  年龄 性别       注册时间
# 0  A1  54  男 2018-08-08
# 1  A2  16  女 2018-08-09
# 2  A3  47  女 2018-08-10
# 3  A4  41  男 2018-08-11

# %%
df2=pd.read_excel(r"H:\对比Excel,轻松学习Python数据分析数据集\4zhang.xlsx",sheet_name="Sheet2")
df2
# Out:
#    编号  年龄 性别       注册时间
# 0  A5  54  男 2018-08-08
# 1  A6  16  女 2018-08-09
# 2  A7  47  女 2018-08-10
# 3  A8  41  男 2018-08-11

# %%
df3=pd.read_excel(r"H:\对比Excel,轻松学习Python数据分析数据集\4zhang.xlsx",sheet_name=0,index_col=0)
df3
#index_col表示用.xlsx文件中的第几列做行索引，从0开始计数
# Out:
#     年龄 性别       注册时间
# 编号
# A1  54  男 2018-08-08
# A2  16  女 2018-08-09
# A3  47  女 2018-08-10
# A4  41  男 2018-08-11

# %%
df4=pd.read_excel(r"H:\对比Excel,轻松学习Python数据分析数据集\4zhang.xlsx",sheet_name=0,header=0)
df4
# Out:
#    编号  年龄 性别       注册时间
# 0  A1  54  男 2018-08-08
# 1  A2  16  女 2018-08-09
# 2  A3  47  女 2018-08-10
# 3  A4  41  男 2018-08-11

# %%
df5=pd.read_excel(r"H:\对比Excel,轻松学习Python数据分析数据集\4zhang.xlsx",sheet_name=0,index_col=0,header=0)
df5
# Out:
#     年龄 性别       注册时间
# 编号
# A1  54  男 2018-08-08
# A2  16  女 2018-08-09
# A3  47  女 2018-08-10
# A4  41  男 2018-08-11

# %%
df6=pd.read_excel(r"H:\对比Excel,轻松学习Python数据分析数据集\4zhang.xlsx",sheet_name=0,header=None)
df6
# Out:
#     0   1   2                    3
# 0  编号  年龄  性别                 注册时间
# 1  A1  54   男  2018-08-08 00:00:00
# 2  A2  16   女  2018-08-09 00:00:00
# 3  A3  47   女  2018-08-10 00:00:00
# 4  A4  41   男  2018-08-11 00:00:00

# %%
df7=pd.read_excel(r"H:\对比Excel,轻松学习Python数据分析数据集\4zhang.xlsx",usecols=0)
df7
# Out:
#    编号
# 0  A1
# 1  A2
# 2  A3
# 3  A4

# %%
df7=pd.read_excel(r"H:\对比Excel,轻松学习Python数据分析数据集\4zhang.xlsx",usecols=[1,2])
df7
# Out:
#    年龄 性别
# 0  54  男
# 1  16  女
# 2  47  女
# 3  41  男

# %%
df7=pd.read_csv(r"H:\对比Excel,轻松学习Python数据分析数据集\4zhang.csv")
df7.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 4 columns):
# 编号      4 non-null object
# 年龄      4 non-null int64
# 性别      4 non-null object
# 注册时间    4 non-null object
# dtypes: int64(1), object(3)
# memory usage: 208.0+ bytes

# %%
df7.describe()
# Out:
#               年龄
# count   4.000000
# mean   39.500000
# std    16.542874
# min    16.000000
# 25%    34.750000
# 50%    44.000000
# 75%    48.750000
# max    54.000000

# %%
df=pd.DataFrame([[20,5000,2],[25,8000,3],[30,9000,3],[28,7000,2]],columns=["年龄","收入","家属数"])
df
# Out:
#    年龄    收入  家属数
# 0  20  5000    2
# 1  25  8000    3
# 2  30  9000    3
# 3  28  7000    2

# %%
df.describe()
# Out:
#               年龄           收入      家属数
# count   4.000000     4.000000  4.00000
# mean   25.750000  7250.000000  2.50000
# std     4.349329  1707.825128  0.57735
# min    20.000000  5000.000000  2.00000
# 25%    23.750000  6500.000000  2.00000
# 50%    26.500000  7500.000000  2.50000
# 75%    28.500000  8250.000000  3.00000
# max    30.000000  9000.000000  3.00000

# %%
df=pd.read_csv(r'H:\对比Excel,轻松学习Python数据分析数据集\4zhang.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 4 columns):
# 编号      4 non-null object
# 年龄      4 non-null int64
# 性别      3 non-null object
# 注册时间    4 non-null object
# dtypes: int64(1), object(3)
# memory usage: 208.0+ bytes

# %%
df.isnull()
# Out:
#       编号     年龄     性别   注册时间
# 0  False  False  False  False
# 1  False  False   True  False
# 2  False  False  False  False
# 3  False  False  False  False

# %%
df
# Out:
#    编号  年龄   性别       注册时间
# 0  A5  54    男   2018/8/8
# 1  A6  16  NaN   2018/8/9
# 2  A7  47    女  2018/8/10
# 3  A8  41    男  2018/8/11

# %%
df.dropna()#删除是空值的整个行
# Out:
#    编号  年龄 性别       注册时间
# 0  A5  54  男   2018/8/8
# 2  A7  47  女  2018/8/10
# 3  A8  41  男  2018/8/11

# %%
df1=pd.read_csv(r'H:\对比Excel,轻松学习Python数据分析数据集\4zhang.csv')
df1
# Out:
#     编号    年龄   性别       注册时间
# 0   A5  54.0    男   2018/8/8
# 1   A6  16.0  NaN   2018/8/9
# 2  NaN   NaN  NaN        NaN
# 3   A7  47.0    女  2018/8/10
# 4   A8  41.0    男  2018/8/11

# %%
df1.isnull()
# Out:
#       编号     年龄     性别   注册时间
# 0  False  False  False  False
# 1  False  False   True  False
# 2   True   True   True   True
# 3  False  False  False  False
# 4  False  False  False  False

# %%
df1.dropna(how='all')#删除空行，只有当整个行都是空值的时候才删除
# Out:
#    编号    年龄   性别       注册时间
# 0  A5  54.0    男   2018/8/8
# 1  A6  16.0  NaN   2018/8/9
# 3  A7  47.0    女  2018/8/10
# 4  A8  41.0    男  2018/8/11

# %%
df1.dropna(how='any')#any只要是表中有空值的  就删除
# Out:
#    编号    年龄 性别       注册时间
# 0  A5  54.0  男   2018/8/8
# 3  A7  47.0  女  2018/8/10
# 4  A8  41.0  男  2018/8/11

# %%
df=pd.read_excel(r'H:\对比Excel,轻松学习Python数据分析数据集\4zhang.xlsx',sheet_name=1)
df
# Out:
#     编号    年龄   性别       注册时间
# 0   A5  54.0    男 2018-08-08
# 1  NaN   NaN  NaN        NaT
# 2   A6  16.0    女 2018-08-09
# 3   A7  47.0  NaN 2018-08-10
# 4   A8  41.0    男 2018-08-11

# %%
df.fillna(0)
# Out:
#    编号    年龄 性别                 注册时间
# 0  A5  54.0  男  2018-08-08 00:00:00
# 1   0   0.0  0                    0
# 2  A6  16.0  女  2018-08-09 00:00:00
# 3  A7  47.0  0  2018-08-10 00:00:00
# 4  A8  41.0  男  2018-08-11 00:00:00

# %%
df.fillna({"性别":"男"})#对性别进行填充
# Out:
#     编号    年龄 性别       注册时间
# 0   A5  54.0  男 2018-08-08
# 1  NaN   NaN  男        NaT
# 2   A6  16.0  女 2018-08-09
# 3   A7  47.0  男 2018-08-10
# 4   A8  41.0  男 2018-08-11

# %%
df.fillna({"性别":"男","年龄":"30"})#分别对性别和年龄进行填充
# Out:
#     编号  年龄 性别       注册时间
# 0   A5  54  男 2018-08-08
# 1  NaN  30  男        NaT
# 2   A6  16  女 2018-08-09
# 3   A7  47  男 2018-08-10
# 4   A8  41  男 2018-08-11

# %%
df=pd.read_excel(r'H:\对比Excel,轻松学习Python数据分析数据集\重复值.xlsx')
df
# Out:
#   订单编号 客户姓名  唯一标识码       成交时间
# 0   A1   张通    101 2018-08-08
# 1   A2   李谷    102 2018-08-09
# 2   A3   孙凤    103 2018-08-10
# 3   A3   孙凤    103 2018-08-10
# 4   A4   赵恒    104 2018-08-11
# 5   A5   赵恒    104 2018-08-12

# %%
df.drop_duplicates()#这段代码是针对这一行所有值进行判断
# Out:
#   订单编号 客户姓名  唯一标识码       成交时间
# 0   A1   张通    101 2018-08-08
# 1   A2   李谷    102 2018-08-09
# 2   A3   孙凤    103 2018-08-10
# 4   A4   赵恒    104 2018-08-11
# 5   A5   赵恒    104 2018-08-12

# %%
df.drop_duplicates(subset='唯一标识码')#我们也可以同样可以针对某一列或某几列进行重复值删除的判断
# Out:
#   订单编号 客户姓名  唯一标识码       成交时间
# 0   A1   张通    101 2018-08-08
# 1   A2   李谷    102 2018-08-09
# 2   A3   孙凤    103 2018-08-10
# 4   A4   赵恒    104 2018-08-11

# %%
df.drop_duplicates(subset=['客户姓名','唯一标识码'])
#也可以利用多列去重，只需要把多个列名以列表的形式传给参数subset即可，比如按姓名和唯一标识码去重
# Out:
#   订单编号 客户姓名  唯一标识码       成交时间
# 0   A1   张通    101 2018-08-08
# 1   A2   李谷    102 2018-08-09
# 2   A3   孙凤    103 2018-08-10
# 4   A4   赵恒    104 2018-08-11

# %%
#不留任何重复值,以上的都是保留一个重复值
df.drop_duplicates(subset=['客户姓名','唯一标识码'],keep=False)
# Out:
#   订单编号 客户姓名  唯一标识码       成交时间
# 0   A1   张通    101 2018-08-08
# 1   A2   李谷    102 2018-08-09

# %%
df
# Out:
#   订单编号 客户姓名  唯一标识码       成交时间
# 0   A1   张通    101 2018-08-08
# 1   A2   李谷    102 2018-08-09
# 2   A3   孙凤    103 2018-08-10
# 3   A3   孙凤    103 2018-08-10
# 4   A4   赵恒    104 2018-08-11
# 5   A5   赵恒    104 2018-08-12

# %%
import pandas as pd
df=pd.read_csv(r'H:\对比Excel,轻松学习Python数据分析数据集\comment.csv')
df
# Out:
#                        time  city  gender             name  level  score  \
# 0       2019-08-13 14:53:57    杭州       1                无      1    5.0
# 1       2019-08-13 14:53:49    上海       0             John      4    5.0
# 2       2019-08-13 14:53:48    黔南       0              权酒歌      1    5.0
# 3       2019-08-13 14:53:44    郑州       2     ZrB836789885      3    4.5
# 4       2019-08-13 14:53:43    信宜       0       陈丽雯『金伙伴广告』      2    5.0
# 5       2019-08-13 14:53:39    台州       0              乔曼珠      1    5.0
# 6       2019-08-13 14:53:37  乌鲁木齐       0            Tupac      2    5.0
# 7       2019-08-13 14:53:36    安吉       1              李建军      2    3.5
# 8       2019-08-13 14:53:28    福州       0     nVL188656855      1    5.0
# 9       2019-08-13 14:53:27    资阳       2              米粒🍭      2    5.0
# 10      2019-08-13 14:53:25    银川       1         我的宝贝叫米娜❤      4    5.0
# 11      2019-08-13 14:53:18   溧水区       2     DhO637401082      2    5.0
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import font_manager
#设置字体的方式
my_font=font_manager.FontProperties(fname="C:\\Windows\\Fonts\\msyh.ttf")

# %%
import pandas as pd
import numpy as np
df=pd.read_excel(r'H:\对比Excel,轻松学习Python数据分析数据集\重复值.xlsx')
df
# Out:
#   订单编号 客户姓名  唯一标识码       成交时间
# 0   A1   张通    101 2018-08-08
# 1   A2   李谷    102 2018-08-09
# 2   A3   孙凤    103 2018-08-10
# 3   A3   孙凤    103 2018-08-10
# 4   A4   赵恒    104 2018-08-11
# 5   A5   赵恒    104 2018-08-12

# %%
df['订单编号'].dtype#查看订单编号这一列的数据类型
# Out:
# dtype('O')

# %%
df['唯一标识码'].dtype
# Out:
# dtype('int64')

# %%
df['唯一标识码'].astype('float64')#将唯一识别码从int类型转换为float类型
# Out:
# 0    101.0
# 1    102.0
# 2    103.0
# 3    103.0
# 4    104.0
# 5    104.0
# Name: 唯一标识码, dtype: float64

# %%
df1=pd.read_excel(r'H:\对比Excel,轻松学习Python数据分析数据集\重复值2.xlsx')
df1
# Out:
#    A1  张通  101 2018-08-08 00:00:00
# 0  A2  李谷  102          2018-08-09
# 1  A3  孙凤  103          2018-08-10
# 2  A3  孙凤  103          2018-08-10
# 3  A4  赵恒  104          2018-08-11
# 4  A5  赵恒  104          2018-08-12

# %%
df1.columns=['订单编号','客户姓名','唯一识别码','成交时间']#为表添加列索引
df1
# Out:
#   订单编号 客户姓名  唯一识别码       成交时间
# 0   A2   李谷    102 2018-08-09
# 1   A3   孙凤    103 2018-08-10
# 2   A3   孙凤    103 2018-08-10
# 3   A4   赵恒    104 2018-08-11
# 4   A5   赵恒    104 2018-08-12

# %%
df1.index=[1,2,3,4,5]
df1
# Out:
#   订单编号 客户姓名  唯一识别码       成交时间
# 1   A2   李谷    102 2018-08-09
# 2   A3   孙凤    103 2018-08-10
# 3   A3   孙凤    103 2018-08-10
# 4   A4   赵恒    104 2018-08-11
# 5   A5   赵恒    104 2018-08-12

# %%
df1.set_index('订单编号')
# Out:
#      客户姓名  唯一识别码       成交时间
# 订单编号
# A2     李谷    102 2018-08-09
# A3     孙凤    103 2018-08-10
# A3     孙凤    103 2018-08-10
# A4     赵恒    104 2018-08-11
# A5     赵恒    104 2018-08-12

# %%
df1
# Out:
#   订单编号 客户姓名  唯一识别码       成交时间
# 1   A2   李谷    102 2018-08-09
# 2   A3   孙凤    103 2018-08-10
# 3   A3   孙凤    103 2018-08-10
# 4   A4   赵恒    104 2018-08-11
# 5   A5   赵恒    104 2018-08-12

# %%
df1.rename(columns={'订单编号':'新订单编号','客户姓名':'新客户姓名'})
# Out:
#   新订单编号 新客户姓名  唯一识别码       成交时间
# 1    A2    李谷    102 2018-08-09
# 2    A3    孙凤    103 2018-08-10
# 3    A3    孙凤    103 2018-08-10
# 4    A4    赵恒    104 2018-08-11
# 5    A5    赵恒    104 2018-08-12

# %%
df1
# Out:
#   订单编号 客户姓名  唯一识别码       成交时间
# 1   A2   李谷    102 2018-08-09
# 2   A3   孙凤    103 2018-08-10
# 3   A3   孙凤    103 2018-08-10
# 4   A4   赵恒    104 2018-08-11
# 5   A5   赵恒    104 2018-08-12

# %%
df.rename(index={1:'一',2:'二'})
# Out:
#   订单编号 客户姓名  唯一标识码       成交时间
# 0   A1   张通    101 2018-08-08
# 一   A2   李谷    102 2018-08-09
# 二   A3   孙凤    103 2018-08-10
# 3   A3   孙凤    103 2018-08-10
# 4   A4   赵恒    104 2018-08-11
# 5   A5   赵恒    104 2018-08-12

# %%
df
# Out:
#   订单编号 客户姓名  唯一标识码       成交时间
# 0   A1   张通    101 2018-08-08
# 1   A2   李谷    102 2018-08-09
# 2   A3   孙凤    103 2018-08-10
# 3   A3   孙凤    103 2018-08-10
# 4   A4   赵恒    104 2018-08-11
# 5   A5   赵恒    104 2018-08-12

# %%
df.rename(columns={'订单编号':'新订单编号','客户姓名':'新客户姓名'},index={1:'一'})
# Out:
#   新订单编号 新客户姓名  唯一标识码       成交时间
# 0    A1    张通    101 2018-08-08
# 一    A2    李谷    102 2018-08-09
# 2    A3    孙凤    103 2018-08-10
# 3    A3    孙凤    103 2018-08-10
# 4    A4    赵恒    104 2018-08-11
# 5    A5    赵恒    104 2018-08-12

# %%
df[['订单编号','客户姓名']]
# Out:
#   订单编号 客户姓名
# 0   A1   张通
# 1   A2   李谷
# 2   A3   孙凤
# 3   A3   孙凤
# 4   A4   赵恒
# 5   A5   赵恒

# %%
df
# Out:
#   订单编号 客户姓名  唯一标识码       成交时间
# 0   A1   张通    101 2018-08-08
# 1   A2   李谷    102 2018-08-09
# 2   A3   孙凤    103 2018-08-10
# 3   A3   孙凤    103 2018-08-10
# 4   A4   赵恒    104 2018-08-11
# 5   A5   赵恒    104 2018-08-12

# %%
df.iloc[:,0:3]
# Out:
#   订单编号 客户姓名  唯一标识码
# 0   A1   张通    101
# 1   A2   李谷    102
# 2   A3   孙凤    103
# 3   A3   孙凤    103
# 4   A4   赵恒    104
# 5   A5   赵恒    104

# %%
df1=df.rename(index={0:'零',1:'一',2:'二',3:'三',4:'四',5:'五'})
df1
# Out:
#   订单编号 客户姓名  唯一标识码       成交时间
# 零   A1   张通    101 2018-08-08
# 一   A2   李谷    102 2018-08-09
# 二   A3   孙凤    103 2018-08-10
# 三   A3   孙凤    103 2018-08-10
# 四   A4   赵恒    104 2018-08-11
# 五   A5   赵恒    104 2018-08-12

# %%
df1.loc['一']
# Out:
# 订单编号                      A2
# 客户姓名                      李谷
# 唯一标识码                    102
# 成交时间     2018-08-09 00:00:00
# Name: 一, dtype: object

# %%
df1.loc[['一','二']]
# Out:
#   订单编号 客户姓名  唯一标识码       成交时间
# 一   A2   李谷    102 2018-08-09
# 二   A3   孙凤    103 2018-08-10

# %%
df1.iloc[0]
# Out:
# 订单编号                      A1
# 客户姓名                      张通
# 唯一标识码                    101
# 成交时间     2018-08-08 00:00:00
# Name: 零, dtype: object

# %%
df1.iloc[[0,1]]
# Out:
#   订单编号 客户姓名  唯一标识码       成交时间
# 零   A1   张通    101 2018-08-08
# 一   A2   李谷    102 2018-08-09

# %%
df1.iloc[0:2]
# Out:
#   订单编号 客户姓名  唯一标识码       成交时间
# 零   A1   张通    101 2018-08-08
# 一   A2   李谷    102 2018-08-09

# %%
df
# Out:
#   订单编号 客户姓名  唯一标识码       成交时间
# 0   A1   张通    101 2018-08-08
# 1   A2   李谷    102 2018-08-09
# 2   A3   孙凤    103 2018-08-10
# 3   A3   孙凤    103 2018-08-10
# 4   A4   赵恒    104 2018-08-11
# 5   A5   赵恒    104 2018-08-12

# %%
df['年龄']=[31,45,23,240,240,56]
df
# Out:
#   订单编号 客户姓名  唯一标识码       成交时间   年龄
# 0   A1   张通    101 2018-08-08   31
# 1   A2   李谷    102 2018-08-09   45
# 2   A3   孙凤    103 2018-08-10   23
# 3   A3   孙凤    103 2018-08-10  240
# 4   A4   赵恒    104 2018-08-11  240
# 5   A5   赵恒    104 2018-08-12   56

# %%
df[df['年龄']<200]#选择年龄小于200的数据
# Out:
#   订单编号 客户姓名  唯一标识码       成交时间  年龄
# 0   A1   张通    101 2018-08-08  31
# 1   A2   李谷    102 2018-08-09  45
# 2   A3   孙凤    103 2018-08-10  23
# 5   A5   赵恒    104 2018-08-12  56

# %%
df[(df['年龄']<200) & (df['唯一标识码']<102)]#选择年龄小于200且唯一识别码小于102的数据
# Out:
#   订单编号 客户姓名  唯一标识码       成交时间  年龄
# 0   A1   张通    101 2018-08-08  31

# %%
df
# Out:
#   订单编号 客户姓名  唯一标识码       成交时间   年龄
# 0   A1   张通    101 2018-08-08   31
# 1   A2   李谷    102 2018-08-09   45
# 2   A3   孙凤    103 2018-08-10   23
# 3   A3   孙凤    103 2018-08-10  240
# 4   A4   赵恒    104 2018-08-11  240
# 5   A5   赵恒    104 2018-08-12   56

# %%
df1.loc[['一','三'],['订单编号','唯一标识码']]#loc方法中的第二对方括号表示列索引的选择，传入列索引名称
# Out:
#   订单编号  唯一标识码
# 一   A2    102
# 三   A3    103

# %%
df1.iloc[[0,1],[0,3]]
# Out:
#   订单编号       成交时间
# 零   A1 2018-08-08
# 一   A2 2018-08-09

# %%
df[df['年龄']<200][['订单编号','年龄']]
# Out:
#   订单编号  年龄
# 0   A1  31
# 1   A2  45
# 2   A3  23
# 5   A5  56

# %%
df.iloc[0:3,0:3]
# Out:
#   订单编号 客户姓名  唯一标识码
# 0   A1   张通    101
# 1   A2   李谷    102
# 2   A3   孙凤    103

# %%
df.iloc[0:3,[0,3]]
# Out:
#   订单编号       成交时间
# 0   A1 2018-08-08
# 1   A2 2018-08-09
# 2   A3 2018-08-10

# %%
df.iloc[0:3,[1,2]]
# Out:
#   客户姓名  唯一标识码
# 0   张通    101
# 1   李谷    102
# 2   孙凤    103

# %%
df.ix[0:3,['客户姓名','唯一标识码']]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
#   客户姓名  唯一标识码
# 0   张通    101
# 1   李谷    102
# 2   孙凤    103
# 3   孙凤    103

# %%
import pandas as pd
import numpy as np
df=pd.read_excel(r'H:\对比Excel,轻松学习Python数据分析数据集\重复值.xlsx',sheet_name=0)
df
# Out:
#   订单编号 客户姓名  唯一标识码       成交时间
# 0   A1   张通    101 2018-08-08
# 1   A2   李谷    102 2018-08-09
# 2   A3   孙凤    103 2018-08-10
# 3   A3   孙凤    103 2018-08-10
# 4   A4   赵恒    104 2018-08-11
# 5   A5   赵恒    104 2018-08-12

# %%
df['唯一标识码'].replace(104,100,inplace=True)
df
# Out:
#   订单编号 客户姓名  唯一标识码       成交时间
# 0   A1   张通    101 2018-08-08
# 1   A2   李谷    102 2018-08-09
# 2   A3   孙凤    103 2018-08-10
# 3   A3   孙凤    103 2018-08-10
# 4   A4   赵恒    100 2018-08-11
# 5   A5   赵恒    100 2018-08-12

# %%
import pandas as pd
import numpy as np
df1=pd.read_excel(r'H:\对比Excel,轻松学习Python数据分析数据集\重复值.xlsx',sheet_name=1)
df1
# Out:
#   订单编号 客户姓名  唯一标识码       成交时间
# 0   A1   张通  101.0 2018-08-08
# 1  NaN  NaN    NaN        NaT
# 2   A2   李谷  102.0 2018-08-09
# 3   A3   孙凤  103.0 2018-08-10
# 4   A3   孙凤  103.0 2018-08-10
# 5   A4   赵恒    NaN 2018-08-11
# 6   A5   赵恒  104.0 2018-08-12

# %%
df1.replace(np.NaN,0)
# Out:
#   订单编号 客户姓名  唯一标识码                 成交时间
# 0   A1   张通  101.0  2018-08-08 00:00:00
# 1    0    0    0.0                    0
# 2   A2   李谷  102.0  2018-08-09 00:00:00
# 3   A3   孙凤  103.0  2018-08-10 00:00:00
# 4   A3   孙凤  103.0  2018-08-10 00:00:00
# 5   A4   赵恒    0.0  2018-08-11 00:00:00
# 6   A5   赵恒  104.0  2018-08-12 00:00:00

# %%
df['年龄']=[240,260,180,40,41,42]
df
# Out:
#   订单编号 客户姓名  唯一标识码       成交时间   年龄
# 0   A1   张通    101 2018-08-08  240
# 1   A2   李谷    102 2018-08-09  260
# 2   A3   孙凤    103 2018-08-10  180
# 3   A3   孙凤    103 2018-08-10   40
# 4   A4   赵恒    100 2018-08-11   41
# 5   A5   赵恒    100 2018-08-12   42

# %%
df.replace([240,260,180],33)
# Out:
#   订单编号 客户姓名  唯一标识码       成交时间  年龄
# 0   A1   张通    101 2018-08-08  33
# 1   A2   李谷    102 2018-08-09  33
# 2   A3   孙凤    103 2018-08-10  33
# 3   A3   孙凤    103 2018-08-10  40
# 4   A4   赵恒    100 2018-08-11  41
# 5   A5   赵恒    100 2018-08-12  42

# %%
df.replace({240:32,260:33,180:34})
# Out:
#   订单编号 客户姓名  唯一标识码       成交时间  年龄
# 0   A1   张通    101 2018-08-08  32
# 1   A2   李谷    102 2018-08-09  33
# 2   A3   孙凤    103 2018-08-10  34
# 3   A3   孙凤    103 2018-08-10  40
# 4   A4   赵恒    100 2018-08-11  41
# 5   A5   赵恒    100 2018-08-12  42

# %%
df['销售']=[1,2,1,2,3,3]
df
# Out:
#   订单编号 客户姓名  唯一标识码       成交时间   年龄  销售
# 0   A1   张通    101 2018-08-08  240   1
# 1   A2   李谷    102 2018-08-09  260   2
# 2   A3   孙凤    103 2018-08-10  180   1
# 3   A3   孙凤    103 2018-08-10   40   2
# 4   A4   赵恒    100 2018-08-11   41   3
# 5   A5   赵恒    100 2018-08-12   42   3

# %%
df.sort_values(by=['销售'])
# Out:
#   订单编号 客户姓名  唯一标识码       成交时间   年龄  销售
# 0   A1   张通    101 2018-08-08  240   1
# 2   A3   孙凤    103 2018-08-10  180   1
# 1   A2   李谷    102 2018-08-09  260   2
# 3   A3   孙凤    103 2018-08-10   40   2
# 4   A4   赵恒    100 2018-08-11   41   3
# 5   A5   赵恒    100 2018-08-12   42   3

# %%
df.sort_values(by=['销售'],ascending=False)
# Out:
#   订单编号 客户姓名  唯一标识码       成交时间   年龄  销售
# 4   A4   赵恒    100 2018-08-11   41   3
# 5   A5   赵恒    100 2018-08-12   42   3
# 1   A2   李谷    102 2018-08-09  260   2
# 3   A3   孙凤    103 2018-08-10   40   2
# 0   A1   张通    101 2018-08-08  240   1
# 2   A3   孙凤    103 2018-08-10  180   1

# %%
df
# Out:
#   订单编号 客户姓名  唯一标识码       成交时间   年龄  销售
# 0   A1   张通    101 2018-08-08  240   1
# 1   A2   李谷    102 2018-08-09  260   2
# 2   A3   孙凤    103 2018-08-10  180   1
# 3   A3   孙凤    103 2018-08-10   40   2
# 4   A4   赵恒    100 2018-08-11   41   3
# 5   A5   赵恒    100 2018-08-12   42   3

# %%
df['销售']
# Out:
# 0    1
# 1    2
# 2    1
# 3    2
# 4    3
# 5    3
# Name: 销售, dtype: int64

# %%
df['平均排名']=df['销售'].rank(method='average')
df
# Out:
#   订单编号 客户姓名  唯一标识码       成交时间   年龄  销售  平均排名
# 0   A1   张通    101 2018-08-08  240   1   1.5
# 1   A2   李谷    102 2018-08-09  260   2   3.5
# 2   A3   孙凤    103 2018-08-10  180   1   1.5
# 3   A3   孙凤    103 2018-08-10   40   2   3.5
# 4   A4   赵恒    100 2018-08-11   41   3   5.5
# 5   A5   赵恒    100 2018-08-12   42   3   5.5

# %%
df['销售'].rank(method='first').astype('int')
# Out:
# 0    1
# 1    3
# 2    2
# 3    4
# 4    5
# 5    6
# Name: 销售, dtype: int32

# %%
df['min']=df['销售'].rank(method='min').astype('int')
df
# Out:
#   订单编号 客户姓名  唯一标识码       成交时间   年龄  销售  平均排名  min
# 0   A1   张通    101 2018-08-08  240   1   1.5    1
# 1   A2   李谷    102 2018-08-09  260   2   3.5    3
# 2   A3   孙凤    103 2018-08-10  180   1   1.5    1
# 3   A3   孙凤    103 2018-08-10   40   2   3.5    3
# 4   A4   赵恒    100 2018-08-11   41   3   5.5    5
# 5   A5   赵恒    100 2018-08-12   42   3   5.5    5

# %%
df['max']=df['销售'].rank(method='max').astype('int')
df
# Out:
#   订单编号 客户姓名  唯一标识码       成交时间   年龄  销售  平均排名  min  max
# 0   A1   张通    101 2018-08-08  240   1   1.5    1    2
# 1   A2   李谷    102 2018-08-09  260   2   3.5    3    4
# 2   A3   孙凤    103 2018-08-10  180   1   1.5    1    2
# 3   A3   孙凤    103 2018-08-10   40   2   3.5    3    4
# 4   A4   赵恒    100 2018-08-11   41   3   5.5    5    6
# 5   A5   赵恒    100 2018-08-12   42   3   5.5    5    6

# %%
df['平均排名']=df['平均排名'].astype('int')
df
# Out:
#   订单编号 客户姓名  唯一标识码       成交时间   年龄  销售  平均排名  min  max
# 0   A1   张通    101 2018-08-08  240   1     1    1    2
# 1   A2   李谷    102 2018-08-09  260   2     3    3    4
# 2   A3   孙凤    103 2018-08-10  180   1     1    1    2
# 3   A3   孙凤    103 2018-08-10   40   2     3    3    4
# 4   A4   赵恒    100 2018-08-11   41   3     5    5    6
# 5   A5   赵恒    100 2018-08-12   42   3     5    5    6

# %%
df.drop(['销售','成交时间'],axis=1)
# Out:
#   订单编号 客户姓名  唯一标识码   年龄  平均排名  min  max
# 0   A1   张通    101  240     1    1    2
# 1   A2   李谷    102  260     3    3    4
# 2   A3   孙凤    103  180     1    1    2
# 3   A3   孙凤    103   40     3    3    4
# 4   A4   赵恒    100   41     5    5    6
# 5   A5   赵恒    100   42     5    5    6

# %%
df.drop(df.columns[[4,5]],axis=1)
# Out:
#   订单编号 客户姓名  唯一标识码       成交时间  平均排名  min  max
# 0   A1   张通    101 2018-08-08     1    1    2
# 1   A2   李谷    102 2018-08-09     3    3    4
# 2   A3   孙凤    103 2018-08-10     1    1    2
# 3   A3   孙凤    103 2018-08-10     3    3    4
# 4   A4   赵恒    100 2018-08-11     5    5    6
# 5   A5   赵恒    100 2018-08-12     5    5    6

# %%
df
# Out:
#   订单编号 客户姓名  唯一标识码       成交时间   年龄  销售  平均排名  min  max
# 0   A1   张通    101 2018-08-08  240   1     1    1    2
# 1   A2   李谷    102 2018-08-09  260   2     3    3    4
# 2   A3   孙凤    103 2018-08-10  180   1     1    1    2
# 3   A3   孙凤    103 2018-08-10   40   2     3    3    4
# 4   A4   赵恒    100 2018-08-11   41   3     5    5    6
# 5   A5   赵恒    100 2018-08-12   42   3     5    5    6

# %%
df.drop(columns=['销售','成交时间'])
# Out:
#   订单编号 客户姓名  唯一标识码   年龄  平均排名  min  max
# 0   A1   张通    101  240     1    1    2
# 1   A2   李谷    102  260     3    3    4
# 2   A3   孙凤    103  180     1    1    2
# 3   A3   孙凤    103   40     3    3    4
# 4   A4   赵恒    100   41     5    5    6
# 5   A5   赵恒    100   42     5    5    6

# %%
df2=df.rename({0:'0a',1:'1b',2:'2c',3:'3d',4:'4e',5:'5f'})
df2
# Out:
#    订单编号 客户姓名  唯一标识码       成交时间   年龄  销售  平均排名  min  max
# 0a   A1   张通    101 2018-08-08  240   1     1    1    2
# 1b   A2   李谷    102 2018-08-09  260   2     3    3    4
# 2c   A3   孙凤    103 2018-08-10  180   1     1    1    2
# 3d   A3   孙凤    103 2018-08-10   40   2     3    3    4
# 4e   A4   赵恒    100 2018-08-11   41   3     5    5    6
# 5f   A5   赵恒    100 2018-08-12   42   3     5    5    6

# %%
df2.drop(['0a','1b'],axis=0)
# Out:
#    订单编号 客户姓名  唯一标识码       成交时间   年龄  销售  平均排名  min  max
# 2c   A3   孙凤    103 2018-08-10  180   1     1    1    2
# 3d   A3   孙凤    103 2018-08-10   40   2     3    3    4
# 4e   A4   赵恒    100 2018-08-11   41   3     5    5    6
# 5f   A5   赵恒    100 2018-08-12   42   3     5    5    6

# %%
df2.drop(df2.index[[1,2]],axis=0)
# Out:
#    订单编号 客户姓名  唯一标识码       成交时间   年龄  销售  平均排名  min  max
# 0a   A1   张通    101 2018-08-08  240   1     1    1    2
# 3d   A3   孙凤    103 2018-08-10   40   2     3    3    4
# 4e   A4   赵恒    100 2018-08-11   41   3     5    5    6
# 5f   A5   赵恒    100 2018-08-12   42   3     5    5    6

# %%
df2.drop(index=['0a','1b'])
# Out:
#    订单编号 客户姓名  唯一标识码       成交时间   年龄  销售  平均排名  min  max
# 2c   A3   孙凤    103 2018-08-10  180   1     1    1    2
# 3d   A3   孙凤    103 2018-08-10   40   2     3    3    4
# 4e   A4   赵恒    100 2018-08-11   41   3     5    5    6
# 5f   A5   赵恒    100 2018-08-12   42   3     5    5    6

# %%
df2
# Out:
#    订单编号 客户姓名  唯一标识码       成交时间   年龄  销售  平均排名  min  max
# 0a   A1   张通    101 2018-08-08  240   1     1    1    2
# 1b   A2   李谷    102 2018-08-09  260   2     3    3    4
# 2c   A3   孙凤    103 2018-08-10  180   1     1    1    2
# 3d   A3   孙凤    103 2018-08-10   40   2     3    3    4
# 4e   A4   赵恒    100 2018-08-11   41   3     5    5    6
# 5f   A5   赵恒    100 2018-08-12   42   3     5    5    6

# %%
df2[df2['年龄']<40]
# Out:
# Empty DataFrame
# Columns: [订单编号, 客户姓名, 唯一标识码, 成交时间, 年龄, 销售, 平均排名, min, max]
# Index: []

# %%
df2
# Out:
#    订单编号 客户姓名  唯一标识码       成交时间   年龄  销售  平均排名  min  max
# 0a   A1   张通    101 2018-08-08  240   1     1    1    2
# 1b   A2   李谷    102 2018-08-09  260   2     3    3    4
# 2c   A3   孙凤    103 2018-08-10  180   1     1    1    2
# 3d   A3   孙凤    103 2018-08-10   40   2     3    3    4
# 4e   A4   赵恒    100 2018-08-11   41   3     5    5    6
# 5f   A5   赵恒    100 2018-08-12   42   3     5    5    6

# %%
df2['销售'].value_counts()
# Out:
# 3    2
# 2    2
# 1    2
# Name: 销售, dtype: int64

# %%
df2['销售'].value_counts()#其中3出现两次  2出现两次  1出现两次
# Out:
# 3    2
# 2    2
# 1    2
# Name: 销售, dtype: int64

# %%
df2['销售']
# Out:
# 0a    1
# 1b    2
# 2c    1
# 3d    2
# 4e    3
# 5f    3
# Name: 销售, dtype: int64

# %%
df2['销售'].value_counts(normalize=True)
# Out:
# 3    0.333333
# 2    0.333333
# 1    0.333333
# Name: 销售, dtype: float64

# %%
df2['销售'].value_counts(normalize=True,sort=False)
# Out:
# 1    0.333333
# 2    0.333333
# 3    0.333333
# Name: 销售, dtype: float64

# %%
df2['销售'].unique()
# Out:
# array([1, 2, 3], dtype=int64)

# %%
from datetime import datetime
datetime.now()
# Out:
# datetime.datetime(2020, 3, 1, 17, 52, 16, 838708)

# %%
datetime.now().year
# Out:
# 2020

# %%
datetime.now().month
# Out:
# 3

# %%
datetime.now().day
# Out:
# 1

# %%
weekday(now()-1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-a83f480ad01d> in <module>
# ----> 1 weekday(now()-1)
#
# NameError: name 'weekday' is not defined

# %%
datetime.now().weekday()+1
# Out:
# 7

# %%
datetime.now().isocalendar()
# Out:
# (2020, 9, 7)

# %%
datetime.now().date()
# Out:
# datetime.date(2020, 3, 1)

# %%
datetime.now().time()
# Out:
# datetime.time(18, 15, 59, 731518)

# %%
datetime.now()
# Out:
# datetime.datetime(2020, 3, 1, 18, 16, 12, 215683)

# %%
datetime.now().strftime('%Y-%m-%d')
# Out:
# '2020-03-01'

# %%
datetime.now().strftime('%Y-%m-%d %H:%M:%S')
# Out:
# '2020-03-01 18:17:48'

# %%
now=datetime.now()
now.date()
# Out:
# datetime.date(2020, 3, 1)

# %%
print(type(now))
# Out:
# <class 'datetime.datetime'>

# %%
print(str(now))
# Out:
# 2020-03-01 18:18:31.436227

# %%
str_time='2018-10-14'
print(str_time)
print(type(str))
# Out:
# 2018-10-14
# <class 'type'>

# %%
from dateutil.parser import parse
a=parse(str_time)#将字符串解析为时间
a.date()
# Out:
# datetime.date(2018, 10, 14)

# %%
import pandas as pd
import numpy as np
df=pd.read_csv(r'H:\对比Excel,轻松学习Python数据分析数据集\train-pivot.csv',encoding='gbk')
df
# Out:
#     用户ID 客户分类    区域 是否省会  7月销量  8月销量  9月销量
# 0  59224   A类  一线城市    是     6    20     0
# 1  55295   B类  三线城市    否    37    27    35
# 2  46035   A类  二线城市    是     8     1     8
# 3   2459   C类  一线城市    是     7     8    14
# 4  22179   B类  三线城市    否     9    12     4
# 5  22557   A类  二线城市    是    42    20    55

# %%
df=pd.read_csv(r'H:\对比Excel,轻松学习Python数据分析数据集\train-pivot.csv',encoding='gbk')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 7 columns):
# 用户ID    6 non-null int64
# 客户分类    6 non-null object
# 区域      6 non-null object
# 是否省会    6 non-null object
# 7月销量    6 non-null int64
# 8月销量    6 non-null int64
# 9月销量    6 non-null int64
# dtypes: int64(4), object(3)
# memory usage: 416.0+ bytes

# %%
df.groupby('客户分类').count()
# Out:
#       用户ID  区域  是否省会  7月销量  8月销量  9月销量
# 客户分类
# A类       3   3     3     3     3     3
# B类       2   2     2     2     2     2
# C类       1   1     1     1     1     1

# %%
df.groupby('客户分类').sum()
# Out:
#         用户ID  7月销量  8月销量  9月销量
# 客户分类
# A类    127816    56    41    63
# B类     77474    46    39    39
# C类      2459     7     8    14

# %%
df.groupby(['客户分类','区域']).count()
# Out:
#            用户ID  是否省会  7月销量  8月销量  9月销量
# 客户分类 区域
# A类   一线城市     1     1     1     1     1
#      二线城市     2     2     2     2     2
# B类   三线城市     2     2     2     2     2
# C类   一线城市     1     1     1     1     1

# %%
df.groupby(['客户分类','区域']).sum()
# Out:
#             用户ID  7月销量  8月销量  9月销量
# 客户分类 区域
# A类   一线城市  59224     6    20     0
#      二线城市  68592    50    21    63
# B类   三线城市  77474    46    39    39
# C类   一线城市   2459     7     8    14

# %%
df.groupby('客户分类')['用户ID'].count()
# Out:
# 客户分类
# A类    3
# B类    2
# C类    1
# Name: 用户ID, dtype: int64

# %%
df['客户分类']
# Out:
# 0    A类
# 1    B类
# 2    A类
# 3    C类
# 4    B类
# 5    A类
# Name: 客户分类, dtype: object

# %%
df.groupby(df['客户分类']).count()
# Out:
#       用户ID  区域  是否省会  7月销量  8月销量  9月销量
# 客户分类
# A类       3   3     3     3     3     3
# B类       2   2     2     2     2     2
# C类       1   1     1     1     1     1

# %%
df.groupby([df['客户分类'],df['区域']]).sum()
# Out:
#             用户ID  7月销量  8月销量  9月销量
# 客户分类 区域
# A类   一线城市  59224     6    20     0
#      二线城市  68592    50    21    63
# B类   三线城市  77474    46    39    39
# C类   一线城市   2459     7     8    14

# %%
df.groupby('客户分类').aggregate(['count','sum'])
# Out:
#       用户ID            区域                是否省会       7月销量      8月销量      9月销量  \
#      count     sum count           sum count  sum count sum count sum count
# 客户分类
# A类       3  127816     3  一线城市二线城市二线城市     3  是是是     3  56     3  41     3
# B类       2   77474     2      三线城市三线城市     2   否否     2  46     2  39     2
# C类       1    2459     1          一线城市     1    是     1   7     1   8     1
#
#
#      sum
# 客户分类
# A类    63
# B类    39
# C类    14

# %%
df.groupby('客户分类').aggregate({'用户ID':'count','7月销量','8月销量':'sum'})
# Out:
#   File "<ipython-input-27-85f581870f1e>", line 1
#     df.groupby('客户分类').aggregate({'用户ID':'count','7月销量','8月销量':'sum'})
#                                                        ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
import numpy as np
df2=pd.read_excel(r'H:\对比Excel,轻松学习Python数据分析数据集\第11章.xlsx',sheet_name=1)
df2
# Out:
#     学号  班级
# 0  100  一班
# 1  101  一班
# 2  102  二班
# 3  103  三班

# %%
import pandas as pd
import numpy as np
df1=pd.read_excel(r'H:\对比Excel,轻松学习Python数据分析数据集\第11章.xlsx',sheet_name=0)
df1
# Out:
#    名次  姓名   学号   成绩
# 0   1  小张  100  650
# 1   2  小王  101  600
# 2   3  小李  102  578
# 3   4  小赵  103  550

# %%
a=pd.merge(df1,df2)
a.to_excel(r'H:\对比Excel,轻松学习Python数据分析数据集\第11章副本.xlsx')

# %%
df3=pd.read_excel(r'H:\对比Excel,轻松学习Python数据分析数据集\第11章.xlsx',sheet_name=2)
df3
# Out:
#    姓名   学号  f_成绩
# 0  小张  100   650
# 1  小王  101   600
# 2  小李  102   578

# %%
df4=pd.read_excel(r'H:\对比Excel,轻松学习Python数据分析数据集\第11章.xlsx',sheet_name=3)
df4
# Out:
#     学号  e_成绩
# 0  100   586
# 1  100   602
# 2  101   691
# 3  101   702
# 4  102   645
# 5  102   676

# %%
pd.merge(df3,df4,on='学号')
# Out:
#    姓名   学号  f_成绩  e_成绩
# 0  小张  100   650   586
# 1  小张  100   650   602
# 2  小王  101   600   691
# 3  小王  101   600   702
# 4  小李  102   578   645
# 5  小李  102   578   676

# %%
pd.merge(df3,df4)
# Out:
#    姓名   学号  f_成绩  e_成绩
# 0  小张  100   650   586
# 1  小张  100   650   602
# 2  小王  101   600   691
# 3  小王  101   600   702
# 4  小李  102   578   645
# 5  小李  102   578   676

# %%
df1
# Out:
#    名次  姓名   学号   成绩
# 0   1  小张  100  650
# 1   2  小王  101  600
# 2   3  小李  102  578
# 3   4  小赵  103  550

# %%
df11=df1.rename(columns={'学号':'编号'})
df11
# Out:
#    名次  姓名   编号   成绩
# 0   1  小张  100  650
# 1   2  小王  101  600
# 2   3  小李  102  578
# 3   4  小赵  103  550

# %%
df2
# Out:
#     学号  班级
# 0  100  一班
# 1  101  一班
# 2  102  二班
# 3  103  三班

# %%
pd.merge(df11,df2,left_on="编号",right_on="学号")
# Out:
#    名次  姓名   编号   成绩   学号  班级
# 0   1  小张  100  650  100  一班
# 1   2  小王  101  600  101  一班
# 2   3  小李  102  578  102  二班
# 3   4  小赵  103  550  103  三班

# %%
df111=df11.set_index('编号')
df111
# Out:
#      名次  姓名   成绩
# 编号
# 100   1  小张  650
# 101   2  小王  600
# 102   3  小李  578
# 103   4  小赵  550

# %%
df2.set_index('学号')
# Out:
#      班级
# 学号
# 100  一班
# 101  一班
# 102  二班
# 103  三班

# %%
df22=df2.set_index('学号')
df22
# Out:
#      班级
# 学号
# 100  一班
# 101  一班
# 102  二班
# 103  三班

# %%
pd.merge(df111,df2,left_index=True,right_on='学号')
# Out:
#    名次  姓名   成绩   学号  班级
# 0   1  小张  650  100  一班
# 1   2  小王  600  101  一班
# 2   3  小李  578  102  二班
# 3   4  小赵  550  103  三班

# %%
df1
# Out:
#    名次  姓名   学号   成绩
# 0   1  小张  100  650
# 1   2  小王  101  600
# 2   3  小李  102  578
# 3   4  小赵  103  550

# %%
df2
# Out:
#     学号  班级
# 0  100  一班
# 1  101  一班
# 2  102  二班
# 3  103  三班

# %%
dff=df2.drop([3])
dff['姓名']=['小张','小王','小李']
dff
# Out:
#     学号  班级  姓名
# 0  100  一班  小张
# 1  101  一班  小王
# 2  102  二班  小李

# %%
pd.merge(df1,dff,on='学号',how='inner')
# Out:
#    名次 姓名_x   学号   成绩  班级 姓名_y
# 0   1   小张  100  650  一班   小张
# 1   2   小王  101  600  一班   小王
# 2   3   小李  102  578  二班   小李

# %%
dff
# Out:
#     学号  班级  姓名
# 0  100  一班  小张
# 1  101  一班  小王
# 2  102  二班  小李

# %%
df1
# Out:
#    名次  姓名   学号   成绩
# 0   1  小张  100  650
# 1   2  小王  101  600
# 2   3  小李  102  578
# 3   4  小赵  103  550

# %%
pd.merge(df1,dff,on='学号',how='left')
# Out:
#    名次 姓名_x   学号   成绩   班级 姓名_y
# 0   1   小张  100  650   一班   小张
# 1   2   小王  101  600   一班   小王
# 2   3   小李  102  578   二班   小李
# 3   4   小赵  103  550  NaN  NaN

# %%
pd.merge(df1,dff,on=['学号','姓名'],how='left')
# Out:
#    名次  姓名   学号   成绩   班级
# 0   1  小张  100  650   一班
# 1   2  小王  101  600   一班
# 2   3  小李  102  578   二班
# 3   4  小赵  103  550  NaN

# %%
pd.merge(df1,dff,on='学号',how='right')
# Out:
#    名次 姓名_x   学号   成绩  班级 姓名_y
# 0   1   小张  100  650  一班   小张
# 1   2   小王  101  600  一班   小王
# 2   3   小李  102  578  二班   小李

# %%
pd.merge(df1,dff,on='学号',how='outer')
# Out:
#    名次 姓名_x   学号   成绩   班级 姓名_y
# 0   1   小张  100  650   一班   小张
# 1   2   小王  101  600   一班   小王
# 2   3   小李  102  578   二班   小李
# 3   4   小赵  103  550  NaN  NaN

# %%
pd.merge(df1,dff,on='学号',how='inner',suffixes=['_wwww','_ooo'])
# Out:
#    名次 姓名_wwww   学号   成绩  班级 姓名_ooo
# 0   1      小张  100  650  一班     小张
# 1   2      小王  101  600  一班     小王
# 2   3      小李  102  578  二班     小李

# %%
df1
# Out:
#    名次  姓名   学号   成绩
# 0   1  小张  100  650
# 1   2  小王  101  600
# 2   3  小李  102  578
# 3   4  小赵  103  550

# %%
import pandas as pd
import numpy as np
df10=pd.read_excel(r'H:\对比Excel,轻松学习Python数据分析数据集\第11章.xlsx',sheet_name=4)
df10
# Out:
#    编号   姓名  班级
# 0   1   许丹  一班
# 1   2  李旭文  一班
# 2   3   程成  一班
# 3   4   赵涛  一班
# 4   5   葛颜  二班

# %%
df2=pd.read_excel(r'H:\对比Excel,轻松学习Python数据分析数据集\第11章.xlsx',sheet_name=5)
df2
# Out:
#    编号  姓名  班级
# 0   1  赵义  二班
# 1   2  李鹏  二班
# 2   3  卫来  二班
# 3   4  葛颜  二班

# %%
df10.set_index('编号')
# Out:
#      姓名  班级
# 编号
# 1    许丹  一班
# 2   李旭文  一班
# 3    程成  一班
# 4    赵涛  一班
# 5    葛颜  二班

# %%
df2.set_index('编号')
# Out:
#     姓名  班级
# 编号
# 1   赵义  二班
# 2   李鹏  二班
# 3   卫来  二班
# 4   葛颜  二班

# %%
pd.concat([df10,df2])
# Out:
#    编号   姓名  班级
# 0   1   许丹  一班
# 1   2  李旭文  一班
# 2   3   程成  一班
# 3   4   赵涛  一班
# 4   5   葛颜  二班
# 0   1   赵义  二班
# 1   2   李鹏  二班
# 2   3   卫来  二班
# 3   4   葛颜  二班

# %%
pd.concat([df10,df2],ignore_index=True)
# Out:
#    编号   姓名  班级
# 0   1   许丹  一班
# 1   2  李旭文  一班
# 2   3   程成  一班
# 3   4   赵涛  一班
# 4   5   葛颜  二班
# 5   1   赵义  二班
# 6   2   李鹏  二班
# 7   3   卫来  二班
# 8   4   葛颜  二班

# %%
pd.concat([df10,df2],ignore_index=True).replace({5:4})
# Out:
#    编号   姓名  班级
# 0   1   许丹  一班
# 1   2  李旭文  一班
# 2   3   程成  一班
# 3   4   赵涛  一班
# 4   4   葛颜  二班
# 5   1   赵义  二班
# 6   2   李鹏  二班
# 7   3   卫来  二班
# 8   4   葛颜  二班

# %%
pd.concat([df10,df2],ignore_index=True).drop_duplicates()
# Out:
#    编号   姓名  班级
# 0   1   许丹  一班
# 1   2  李旭文  一班
# 2   3   程成  一班
# 3   4   赵涛  一班
# 4   5   葛颜  二班
# 5   1   赵义  二班
# 6   2   李鹏  二班
# 7   3   卫来  二班
# 8   4   葛颜  二班

# %%
a=pd.concat([df10,df2],ignore_index=True).drop_duplicates()
a
# Out:
#    编号   姓名  班级
# 0   1   许丹  一班
# 1   2  李旭文  一班
# 2   3   程成  一班
# 3   4   赵涛  一班
# 4   5   葛颜  二班
# 5   1   赵义  二班
# 6   2   李鹏  二班
# 7   3   卫来  二班
# 8   4   葛颜  二班

# %%
a=pd.concat([df10,df2],ignore_index=True).replace({5:4})
a
# Out:
#    编号   姓名  班级
# 0   1   许丹  一班
# 1   2  李旭文  一班
# 2   3   程成  一班
# 3   4   赵涛  一班
# 4   4   葛颜  二班
# 5   1   赵义  二班
# 6   2   李鹏  二班
# 7   3   卫来  二班
# 8   4   葛颜  二班

# %%
b=a.drop_duplicates()

# %%
b
# Out:
#    编号   姓名  班级
# 0   1   许丹  一班
# 1   2  李旭文  一班
# 2   3   程成  一班
# 3   4   赵涛  一班
# 4   4   葛颜  二班
# 5   1   赵义  二班
# 6   2   李鹏  二班
# 7   3   卫来  二班

# %%
b.iloc[4,0]='lal'
b
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#     编号   姓名  班级
# 0    1   许丹  一班
# 1    2  李旭文  一班
# 2    3   程成  一班
# 3    4   赵涛  一班
# 4  lal   葛颜  二班
# 5    1   赵义  二班
# 6    2   李鹏  二班
# 7    3   卫来  二班

# %%
b.loc['4',:]
b
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: '4'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-90-8e6446a65963> in <module>
# ----> 1 b.loc['4',:]
#       2 b
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
# ...
